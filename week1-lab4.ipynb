# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(12345)

x_train = np.array([1, 1.74, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5])
y_train = np.array(x + rng.normal(0, 0.5, size=x.shape))


x_grid = np.linspace(0, 10, 100)
y_grid = np.linspace(0, 10, 100)
X, Y = np.meshgrid(x_grid, y_grid)

def model(x, w, b):
    return w * x + b
plt.scatter(x_train,y_train,marker='x', c='r')
plt.plot(x_train, model(x_train, 1, 0), c='b')
plt.show()


def cost(w, b, x, y):
    return (w * x + b - y) * (w * x + b - y)
J = np.vectorize(lambda w, b: cost(w, b, x_train, model(x_train, 1, 0)).sum()/2*len(x_train))
plt.contour(X, Y, J(X, Y), levels=100)

# %%
class Cost:
    def __init__(self, w, b):
        self.w = w
        self.b = b
    def __call__(self, x, y, model):
        return np.sum((y - (w * x + b))**2)
