# %%
import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(12345)

x_i = np.array([1, 1.74, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5])
y_i = np.array(x_i + rng.normal(0, 0.5, size=x_i.shape))
X, Y = np.meshgrid(np.linspace(0,10,100), np.linspace(0,10,100))

def f(w, b):
    return w * x_i + b

def cost(w, b):
    return np.sum((f(w, b) - y_i)**2)/2*len(x_i)
J = np.vectorize(cost)

plt.scatter(x_i,y_i,marker='x', c='r')
plt.plot(x_i, y(1, 0), c='b')
plt.show()

# %%
plt.contour(X, Y, J(X, Y), levels=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 plt.contour(X, Y, J(X, Y), levels=100)
#       2 plt.show()
#
# Cell In[19], line 14, in J(w, b)
#      13 def J(w, b):
# ---> 14     return np.sum((f(w, b) - y_i)**2)/2*len(x_i)
#
# Cell In[19], line 11, in f(w, b)
#      10 def f(w, b):
# ---> 11     return w * x_i + b
#
# ValueError: operands could not be broadcast together with shapes (100,100) (10,)

# %%
class Cost:
    def __init__(self, w, b):
        self.w = w
        self.b = b
    def __call__(self, x, y, model):
        return np.sum((y - (w * x + b))**2)
